# %% [markdown]
# # Project X -- [Prisha] [Joshi]

# %% [markdown]
# **TA Help:** John Smith, Alice Jones
#
# - Help with figuring out how to write a function.
#
# **Collaboration:** Friend1, Friend2
#
# - Helped figuring out how to load the dataset.
# - Helped debug error with my plot.

# %% [markdown]
# ## Question 1

# %%
library(data.table)
myDF <- fread("/anvil/projects/tdm/data/flights/subset/1990.csv")
tapply(myDF$ArrDelay,myDF$Dest,mean, na.rm = TRUE)
sort(tapply(myDF$ArrDelay,myDF$Dest,mean, na.rm = TRUE))
# Out:
#         ABE         ABQ         ACY         AGS         ALB         AMA
#   4.7749400   7.7720134   5.5880759   8.3583853   7.5112601   8.5679871
#         ANC         ATL         ATW         AUS         AVL         AVP
#  11.3615363   8.5970350 -11.2530120   6.2188843   5.5619174   7.2391017
#         AZO         BDL         BET         BFL         BGM         BGR
#   3.3342525   7.5015869  11.8017544   5.7055990   4.6090188  11.6194061
#         BHM         BIL         BIS         BLI         BNA         BOI
#   5.6182156   4.3069083   4.3256917   6.5716630   2.9905406   7.8021441
#         BOS         BTM         BTR         BTV         BUF         BUR
#   8.6813895   6.1114327   7.7275846   7.1847366   7.6238587   2.9779121
#         BWI         BZN         CAE         CAK         CCR         CDV
#   6.1178011   6.0083052   8.4543987   5.6934813   1.0583596   8.3764881
#         CHA         CHO         CHS         CID         CLE         CLT
# ...

# %% [markdown]
# The average arrival delay arriving to each aiport can be seen by appyling the tapply(mean) function. as we can see with the sort function the airport: PSE has the highest mean arrival delay time with the value of 30.5333333333333

# %% [markdown]
# ## Question 2

# %%
# code here
library(data.table)
DF <- fread ("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")
tapply(DF$SPEND, DF$STORE_R ,sum)
# Out:
#  CENTRAL     EAST    SOUTH     WEST
#  8897305 11699447  7957921  9680107

# %% [markdown]
# the sum of the amount spent in each store is given above with the stores namely: central,east,south,and west.

# %% [markdown]
# ## Question 3

# %%
# code here
library(data.table)
DF <- fread ("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")
tapply(DF$SPEND, DF$YEAR ,sum)
# Out:
#     2016     2017
# 19051720 19183059

# %% [markdown]
# the total amount spent in the year 2016 and 2017 can be seen. the year 2017 had more money spent that 2016. that means that grocery saled were higher in 2017 than 2016

# %% [markdown]
# ## Question 4

# %%
# code here
library(data.table)
DF1 <- fread("/anvil/projects/tdm/data/olympics/athlete_events.csv")
tapply(DF1$Height,DF1$NOC, mean, na.rm = TRUE)
# Out:
#      AFG      AHO      ALB      ALG      AND      ANG      ANT      ANZ
# 170.5926 177.2941 173.0000 174.7029 173.7037 178.2041 175.1217 176.7308
#      ARG      ARM      ARU      ASA      AUS      AUT      AZE      BAH
# 176.6047 171.9378 173.2195 175.6667 176.8740 177.3697 172.7174 177.4407
#      BAN      BAR      BDI      BEL      BEN      BER      BHU      BIH
# 166.1875 176.5990 172.6316 176.1432 173.6833 177.4058 166.5172 178.6339
#      BIZ      BLR      BOH      BOL      BOT      BRA      BRN      BRU
# 175.0548 174.2564 174.0000 171.2957 175.8095 177.6371 173.4245 166.1111
#      BUL      BUR      CAF      CAM      CAN      CAY      CGO      CHA
# 172.8309 176.0000 179.2766 166.7193 174.9787 179.5068 174.5854 176.5588
#      CHI      CHN      CIV      CMR      COD      COK      COL      COM
# 174.9870 172.6027 176.4151 173.6346 175.3582 171.3243 169.9152 170.8667
#      CPV      CRC      CRO      CRT      CUB      CYP      CZE      DEN
# ...

# %% [markdown]
# the average height of an athelete in each country can be seen above.

# %% [markdown]
# ## Question 5

# %%
# code here
library(data.table)
DF1 <- fread("/anvil/projects/tdm/data/olympics/athlete_events.csv")
tapply(DF1$Height,DF1$Sport, mean, na.rm = TRUE)
avg <- tapply(DF1$Height,DF1$Sport, mean, na.rm = TRUE)
# Out:
#               Aeronautics             Alpine Skiing                  Alpinism
#                       NaN                  173.4891                       NaN
#                   Archery          Art Competitions                 Athletics
#                  173.2031                  174.6441                  176.2563
#                 Badminton                  Baseball                Basketball
#                  174.1788                  182.5993                  190.8699
#             Basque Pelota          Beach Volleyball                  Biathlon
#                       NaN                  186.1450                  174.0348
#                 Bobsleigh                    Boxing                  Canoeing
#                  181.4375                  172.8257                  178.5396
#                   Cricket                   Croquet      Cross Country Skiing
#                       NaN                       NaN                  173.2492
# ...

# %%
sort(avg)
# Out:
#                Gymnastics              Trampolining                    Diving
#                  162.9360                  166.5828                  166.6343
#             Weightlifting       Rhythmic Gymnastics            Figure Skating
#                  167.8248                  167.8703                  168.2022
#     Synchronized Swimming                  Softball Short Track Speed Skating
#                  168.4815                  169.3951                  170.1082
#          Freestyle Skiing              Table Tennis                 Wrestling
#                  171.0130                  171.2538                  172.3586
#                    Boxing              Snowboarding                   Archery
#                  172.8257                  173.0856                  173.2031
#      Cross Country Skiing                    Hockey             Alpine Skiing
#                  173.2492                  173.3597                  173.4891
# ...

# %% [markdown]
# the averga eheight in each sports can be seen above. Gymnastics has the lowest avergae height with 162.936019719216 and Basketball has the highest average height of 190.869878897191

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
