# %% [markdown]
# # Project X -- [Prisha] [Joshi]

# %% [markdown]
# **TA Help:** John Smith, Alice Jones
#
# - Help with figuring out how to write a function.
#
# **Collaboration:** Friend1, Friend2
#
# - Helped figuring out how to load the dataset.
# - Helped debug error with my plot.

# %% [markdown]
# ## Question 1

# %%
library(data.table)
options(repr.matrix.max.cols=50)
df <- fread("/anvil/projects/tdm/data/iowa_liquor_sales/iowa_liquor_sales.csv", nrows= 1000)
df
df1<- fread("/anvil/projects/tdm/data/iowa_liquor_sales/iowa_liquor_sales.csv", select = c(3:7))
df1
# Out:
#      Invoice/Item Number Date       Store Number
# 1    S07122800016        08/16/2012 2846
# 2    S21151400007        09/10/2014 3894
# 3    S11572100060        04/10/2013 2558
# 4    S07453200005        08/30/2012 4680
# 5    S23684100152        01/26/2015 2590
# 6    S06685900003        07/19/2012 4126
# 7    S15834500013        11/20/2013 3417
# 8    S15311500002        10/23/2013 4818
# 9    S05332900031        05/02/2012 3403
# 10   S10889600059        03/04/2013 3565
# 11   S26804000069        07/16/2015 2595
# 12   S25479500173        05/05/2015 2508
# 13   S03636900001        01/18/2012 3645
# 14   S12172100006        05/13/2013 4007
# 15   S09751900060        12/27/2012 2633
# 16   S10514100018        02/11/2013 4525
# 17   S16590600035        12/30/2013 3964
# 18   S03760800002        01/26/2012 2554
# 19   S10214500010        01/24/2013 4622
# 20   S04435900021        03/07/2012 3621
# 21   S14609800010        09/17/2013 3676
# 22   S22180700028        11/04/2014 5032
# ...

# %% [markdown]
# Columns 3,4,5,6,and 7 have contain the Store number , name, address, city and zip code respectively. the dimension is 5 * 27050143

# %% [markdown]
# ## Question 2

# %%
library(data.table)
# ten most popular store numbers
df1 <- fread("/anvil/projects/tdm/data/iowa_liquor_sales/iowa_liquor_sales.csv", select = c(3:7))
store_number <- sort(table(df1$'Store Number'),decreasing = TRUE)
head(store_number , 10)
# ten most popular store names 
store_name <- sort(table(df1$'Store Name'),decreasing = TRUE)
head(store_name ,10)
#zip, address and city pasted together 
acz_ten <- sort(table(paste(df1$Address , df1$City , df1$'Zip Code')))
head(acz_ten , 10)
# Out:
#   2633   4829   2190   2512   2572   2603   2515   2614   2647   2648
# 223447 190702 173109 147581 142536 140319 133959 132915 132269 128608
#         HY-VEE #3 / BDI / DES MOINES                       CENTRAL CITY 2
#                               223447                               190653
#            CENTRAL CITY LIQUOR, INC.      HY-VEE FOOD STORE / CEDAR FALLS
#                               173158                               142536
#  HY-VEE WINE AND SPIRITS / IOWA CITY HY-VEE WINE AND SPIRITS / BETTENDORF
#                               141557                               140319
#             HY-VEE #7 / CEDAR RAPIDS                      HY-VEE #4 / WDM
#                               131294                               128608
#    HY-VEE FOOD STORE #1 / MASON CITY                    BENZ DISTRIBUTING
#                               127264                               120357
#                                 DUBUQUE 52002
#                                             1
# ...

# %% [markdown]
# no, the answers in paqrt a and b dont exactly agree and neither do they agree in part a and c.

# %% [markdown]
# ## Question 3

# %%
library(data.table)
df1 <- fread("/anvil/projects/tdm/data/iowa_liquor_sales/iowa_liquor_sales.csv", select = c(7,12,22))
code_sales <- tapply(df1$'Sale (Dollars)', df1$'Zip Code', sum)
top_ten <- sort(code_sales, decreasing = TRUE )
print(head(top_ten , 10 ))
name_sales <- tapply( df1$'Sale (Dollars)',df1$'Category Name', sum)
top_ten_category <- sort(name_sales , decreasing = TRUE)
print(head(top_ten_category , 10 ))
# Out:
#     50320     52402     52240     50266     51501     52241     50613     50311
# 132861227 108460935 106827909  95956449  84485599  80224356  70716357  65407917
#     52722     50021
#  63447651  61328202
#         CANADIAN WHISKIES           AMERICAN VODKAS STRAIGHT BOURBON WHISKIES
#                 457612891                 380307151                 257794862
#                SPICED RUM           WHISKEY LIQUEUR           IMPORTED VODKAS
#                 254362805                 199736755                 183082359
#        TENNESSEE WHISKIES        100% AGAVE TEQUILA          BLENDED WHISKIES
#                 162676709                 124223944                 109152591
#         IMPORTED BRANDIES
#                  88413646

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 4

# %%
library(data.table)
df2 <- fread("/anvil/projects/tdm/data/election/itcont2020.txt" , select = c (10,15))
head(df2)
state_sales <- tapply(df2$V15, df2$V10 , sum )
top_ten_sales <- sort(state_sales , decreasing = TRUE)
print(head(top_ten_sales , 10 ))
# Out:
# Warning message in fread("/anvil/projects/tdm/data/election/itcont2020.txt", select = c(10, :
# "Found and resolved improper quoting out-of-sample. First healed line 543881: <<C00401224|A|M10||202012149381299609|24T|IND|YOUNG, BRUCE|SARANAC LAKE|NY|12983|"SELF" (EMPLOYER WISHES TO REMAIN ANON|IND. CONTRACTOR / CARETAKER|09292020|27|C00649061|SA11AI_310755484|1482832||EARMARKED FOR COMMITTEE TO ELECT TEDRA COBB (C00649061)|4012120212130550457>>. If the fields are not quoted (e.g. field separator does not appear within any field), try quote="" to avoid this warning."
#   V10 V15
# 1 TX   25
# 2 MO  100
# 3 FL    5
# 4 FL    5
# 5 FL   50
# 6 CA  100
#         CA         NY         VA         DC         TX         FL         IL
# 2803518256 2521628477 1122819081 1060820708 1005943807  913762179  610913249
#         MA         NV         WA
#  521866708  384867853  384169499

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 5

# %%
library(data.table)
data <- fread("/anvil/projects/tdm/data/movies_and_tv/imdb2024/basics.tsv" )
head(data , nrows = 10 )
data$genres

strsplit(data$genres, ',')

unlist(strsplit(data$genres, ','))

table(unlist(strsplit(data$genres, ',')))
# Out:
# Warning message in fread("/anvil/projects/tdm/data/movies_and_tv/imdb2024/basics.tsv"):
# "Found and resolved improper quoting out-of-sample. First healed line 242860: <<tt0253684	tvEpisode	"Rome br<c3><bb>le" (Portrait de Shirley Clarke)	"Rome br<c3><bb>le" (Portrait de Shirley Clarke)	0	1970		54	Documentary>>. If the fields are not quoted (e.g. field separator does not appear within any field), try quote="" to avoid this warning."
#   tconst    titleType primaryTitle           originalTitle          isAdult
# 1 tt0000001 short     Carmencita             Carmencita             0
# 2 tt0000002 short     Le clown et ses chiens Le clown et ses chiens 0
# 3 tt0000003 short     Poor Pierrot           Pauvre Pierrot         0
# 4 tt0000004 short     Un bon bock            Un bon bock            0
# 5 tt0000005 short     Blacksmith Scene       Blacksmith Scene       0
# 6 tt0000006 short     Chinese Opium Den      Chinese Opium Den      0
#   startYear endYear runtimeMinutes genres
# ...

# %%
library(data.table)
data2 <- fread("/anvil/projects/tdm/data/movies_and_tv/imdb2024/basics.tsv", select = "genres")
head(data2$genres)
all_genres <- unlist(strsplit(data2$genres, ','))
genre_counts <- table(all_genres)
sorted_genre_counts <- sort(genre_counts, decreasing = TRUE)
head(sorted_genre_counts,10)
# Out:
# Warning message in fread("/anvil/projects/tdm/data/movies_and_tv/imdb2024/basics.tsv", :
# "Found and resolved improper quoting out-of-sample. First healed line 242860: <<tt0253684	tvEpisode	"Rome br<c3><bb>le" (Portrait de Shirley Clarke)	"Rome br<c3><bb>le" (Portrait de Shirley Clarke)	0	1970		54	Documentary>>. If the fields are not quoted (e.g. field separator does not appear within any field), try quote="" to avoid this warning."
# [1] "Documentary,Short"        "Animation,Short"
# [3] "Animation,Comedy,Romance" "Animation,Short"
# [5] "Comedy,Short"             "Short"
# all_genres
#       Drama      Comedy   Talk-Show       Short Documentary        News
#     3151064     2181847     1372500     1191319     1062294     1051399
#     Romance      Family  Reality-TV   Animation
#     1045327      824607      624854      556566

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
